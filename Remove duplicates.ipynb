# %%
import cv2 as cv
import time
from datetime import timedelta
import os
import pandas as pd
from helper import calculateDistance, delete_duplicate_keep_best, draw_craters_rectangles

# the raw data to process for duplicate removal
csv_path = 'results/crater_25_nn.csv'

# the image for drawing rectangles
img_path = os.path.join('crater_data', 'images', 'tile3_25.pgm')

data = pd.read_csv(csv_path, header=None)

start_time = time.time()

# first pass, remove duplicates for points of same window size
df1 = {}
for ws in data[2].unique():
    df1[ws] = data[ (data[3] > 0.75) & (data[2] == ws) ] # take only 75% or higher confidence
    df1[ws] = delete_duplicate_keep_best(df1[ws])

# Start merging process
# We will add points of greatest size first
# then merge with the next smaller size and remove duplicates
# Do this until the smallest window size has been included

merge = pd.DataFrame()
for ws in reversed(sorted(df1.keys())):
    merge = pd.concat([merge, df1[ws]])
    old_size = len(merge)
    merge = delete_duplicate_keep_best(merge) # we can tweak ws for eliminations
    new_size = len(merge)
    print("Processed window size", ws, ", considered", old_size, "points, returned", new_size, "points")

img = draw_craters_rectangles(img_path, merge, show_probs=False)
cv.imwrite("%s.jpg" % (csv_path.split('.')[0]), img, [int(cv.IMWRITE_JPEG_QUALITY), 100])
merge[[0,1,2]].to_csv("%s_noduplicates.csv" % (csv_path.split('.')[0]), header=False, index=False)

end_time = time.time()
time_dif = end_time - start_time
print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))
# Out:
# Processed window size 1076 , considered 2 points, returned 1 points
# Processed window size 999 , considered 2 points, returned 1 points
# Processed window size 922 , considered 3 points, returned 2 points
# Processed window size 845 , considered 3 points, returned 2 points
# Processed window size 768 , considered 4 points, returned 3 points
# Processed window size 717 , considered 7 points, returned 4 points
# Processed window size 666 , considered 8 points, returned 3 points
# Processed window size 615 , considered 8 points, returned 3 points
# Processed window size 563 , considered 8 points, returned 4 points
# Processed window size 512 , considered 10 points, returned 4 points
# Processed window size 478 , considered 11 points, returned 5 points
# Processed window size 444 , considered 12 points, returned 5 points
# Processed window size 410 , considered 12 points, returned 5 points
# Processed window size 375 , considered 13 points, returned 5 points
# Processed window size 341 , considered 13 points, returned 5 points
# Processed window size 318 , considered 15 points, returned 7 points
# Processed window size 296 , considered 17 points, returned 8 points
# Processed window size 273 , considered 20 points, returned 8 points
# Processed window size 250 , considered 22 points, returned 10 points
# Processed window size 227 , considered 23 points, returned 11 points
# Processed window size 212 , considered 30 points, returned 15 points
# Processed window size 197 , considered 33 points, returned 17 points
# Processed window size 182 , considered 40 points, returned 18 points
# Processed window size 167 , considered 41 points, returned 21 points
# Processed window size 151 , considered 47 points, returned 23 points
# Processed window size 141 , considered 70 points, returned 34 points
# Processed window size 131 , considered 85 points, returned 40 points
# Processed window size 121 , considered 86 points, returned 42 points
# Processed window size 111 , considered 95 points, returned 50 points
# Processed window size 101 , considered 106 points, returned 57 points
# Processed window size 94 , considered 138 points, returned 64 points
# Processed window size 87 , considered 157 points, returned 76 points
# Processed window size 81 , considered 173 points, returned 87 points
# Processed window size 74 , considered 191 points, returned 94 points
# Processed window size 67 , considered 212 points, returned 115 points
# Processed window size 63 , considered 284 points, returned 140 points
# Processed window size 58 , considered 333 points, returned 165 points
# Processed window size 54 , considered 368 points, returned 181 points
# Processed window size 49 , considered 403 points, returned 210 points
# Processed window size 45 , considered 434 points, returned 234 points
# Processed window size 42 , considered 535 points, returned 269 points
# Processed window size 39 , considered 584 points, returned 303 points
# Processed window size 36 , considered 634 points, returned 340 points
# Processed window size 33 , considered 679 points, returned 369 points
# Processed window size 30 , considered 717 points, returned 419 points
# Processed window size 28 , considered 857 points, returned 483 points
# Processed window size 26 , considered 914 points, returned 530 points
# Processed window size 24 , considered 954 points, returned 565 points
# Processed window size 22 , considered 963 points, returned 603 points
# Processed window size 20 , considered 969 points, returned 632 points
# Time usage: 0:00:26
